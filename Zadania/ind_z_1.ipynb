# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
plt.plot([0,5,10,15,20,25,30], [10,25,40,50,55,57,58], 'b--o')
plt.title('Отжимания по минутам')
plt.xlabel('Мин')
plt.ylabel('Отжимания')
plt.grid()
plt.show()
