# %%
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams['text.usetex'] = True
plt.rcParams['text.latex.preamble'] = r'''
\usepackage[T2A]{fontenc}
\usepackage[utf8]{inputenc}
\usepackage[russian]{babel}
'''

# %%
x = np.linspace(0, 10, 50)
y = x
plt.title(r'\textbf{Линейная зависимость} $y=x$')
plt.xlabel(r'$x$ ')
plt.ylabel(r'$y(x)$')
plt.grid(True)

plt.plot(x, y)
plt.show()

# %%
import numpy as np
x = np.linspace(0,10,50)
y=x
plt.title(r'\textbf{Линейная зависимость} $y=x$')
plt.xlabel(r'$x$ ')
plt.ylabel(r'$y(x)$')
plt.grid(True)
plt.plot(x,y,"r--")
plt.show()

# %%
x = np.linspace(0,10,50)
y1 = x
y2 = [i**2 for i in x]
plt.title(r'\textbf{Зависимость} $y1=x$ и $y2=x^2$')
plt.xlabel(r'$x$')
plt.ylabel(r'$y1(x)$  $y2(x)$')
plt.grid(True)

plt.plot(x,y1,x,y2)
plt.show()

# %%
fruits = ["apple", "peache", "orange", "bannana", "melon"]
count = [34,25,43,31,17]
plt.bar(fruits, count)
plt.title(r'Fruit')
plt.xlabel(r'Fruit')
plt.ylabel(r'Counts')
plt.grid(True)
plt.show()

# %%
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter, AutoMinorLocator)
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0,10,10)
y1 = 4*x
y2 = [i**2 for i in x]

fig, ax = plt.subplots(figsize = (8,6))

ax.set_title(r'$Y1=4X, Y2=X^2$', fontsize=16)  # Убрал b', добавил r для raw-строки
ax.set_xlabel("x",fontsize=14)
ax.set_ylabel("y1, y2",fontsize=14)
ax.grid(which="major",linewidth=1.2)
ax.grid(which="minor",linestyle="--", color="gray", linewidth=0.5)

ax.scatter(x, y2, label=r"$y2 = X^2$")  # Тоже добавил математический режим
ax.legend()

ax.xaxis.set_minor_locator(AutoMinorLocator())
ax.yaxis.set_minor_locator(AutoMinorLocator())

ax.tick_params(which='major',length=10, width=2)
ax.tick_params(which='minor',length=5, width=1)

plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot()
plt.show()

# %%
plt.plot([1,7,3,5,11,1])
plt.xlabel(r'$x$')
plt.ylabel(r'$y$')
plt.grid(True)
plt.show()

# %%
plt.plot([1,5,10,15,20], [1,7,3,5,11])
plt.xlabel(r'$x$')
plt.ylabel(r'$y$')
plt.grid(True)
plt.show()

# %%
plt.xlabel('Day', fontsize=15, color='blue')
plt.show()

# %%
import matplotlib.pyplot as plt

x = [1, 5, 10, 15, 20]
y = [1, 7, 3, 5, 11]

plt.plot(x, y, label=r'$steel\ price$') 
plt.title(r'$Chart\ price$', fontsize=15) 
plt.xlabel(r'$Day$', fontsize=12, color='blue') 
plt.ylabel(r'$Price$', fontsize=12, color='blue') 

plt.legend()
plt.grid(True)
plt.text(15, 4, r'$grow\ up!$') 
plt.show()

# %%
plt.text(1,1,'type: Steel')
plt.show()

# %%
plt.plot(x,y, color='red')
plt.xlabel(r'$x$', fontsize=12, color='blue') 
plt.ylabel(r'$y$', fontsize=12, color='blue') 
plt.show()

# %%
x = [1,5,10,15,20]
y = [1,7,3,5,11]
plt.xlabel(r'$x$', fontsize=12, color='blue') 
plt.ylabel(r'$y$', fontsize=12, color='blue') 
plt.plot(x, y, '--')
plt.show()

# %%
x = [1,5,10,15,20]
y = [1,7,3,5,11]
plt.xlabel(r'$x$', fontsize=12, color='blue') 
plt.ylabel(r'$y$', fontsize=12, color='blue') 
line = plt.plot(x, y)
plt.setp(line, linestyle='--')
plt.show()

# %%
x = [1,5,10,15,20]
y1 = [1,7,3,5,11]
y2 = [i*1.2 + 1 for i in y1]
y3 = [i*1.2 + 1 for i in y2]
y4 = [i*1.2 + 1 for i in y3]
plt.xlabel(r'$x$', fontsize=12, color='blue') 
plt.ylabel(r'$y$', fontsize=12, color='blue') 
plt.plot(x, y1, '-', x, y2, '--', x, y3, '-.', x, y4, ':')

# %%
plt.plot(x,y1,'-')
plt.plot(x,y2,'--')
plt.plot(x,y3,'-.')
plt.xlabel(r'$x$', fontsize=12, color='blue') 
plt.ylabel(r'$y$', fontsize=12, color='blue') 
plt.plot(x,y4,':');

# %%
x = [1,5,10,15,20]
y = [1,7,3,5,11]
plt.xlabel(r'$x$', fontsize=12, color='blue') 
plt.ylabel(r'$y$', fontsize=12, color='blue') 
plt.plot(x,y,'--r');

# %%
plt.plot(x,y,'ro')
plt.xlabel(r'$x$', fontsize=12, color='blue') 
plt.ylabel(r'$y$', fontsize=12, color='blue') ;

# %%
plt.plot(x, y, 'bx')
plt.xlabel(r'$x$', fontsize=12, color='blue') 
plt.ylabel(r'$y$', fontsize=12, color='blue') ;

# %%
x = [1,5,10,15,20]
y1 = [1,7,3,5,11]
y2 = [i*1.2 + 1 for i in y1]
y3 = [i*1.2 + 1 for i in y2]
y4 = [i*1.2 + 1 for i in y3]

plt.figure(figsize=(12,7))
plt.subplot(2,2,1)
plt.xlabel(r'$x$')
plt.ylabel(r'$y1$')
plt.grid(True)
plt.plot(x,y1,'-'
plt.subplot(2,2,2)
plt.xlabel(r'$x$')
plt.ylabel(r'$y2$')
plt.grid(True)
plt.plot(x,y2,'--')
plt.subplot(2,2,3)
plt.xlabel(r'$x$')
plt.ylabel(r'$y3$')
plt.grid(True)
plt.plot(x,y3,'-.')
plt.subplot(2,2,4)
plt.xlabel(r'$x$')
plt.ylabel(r'$y4$')
plt.grid(True)
plt.plot(x,y4,':');

# %%
plt.subplot(221)
plt.plot(x, y1, '-')
plt.xlabel(r'$x$', fontsize=12)
plt.ylabel(r'$y_1$', fontsize=12)

plt.grid(True)

plt.subplot(222)
plt.plot(x, y2, '--')
plt.xlabel(r'$x$', fontsize=12)
plt.ylabel(r'$y_2$', fontsize=12)

plt.grid(True)

plt.subplot(223)
plt.plot(x, y3, '-.')
plt.xlabel(r'$x$', fontsize=12)
plt.ylabel(r'$y_3$', fontsize=12)

plt.grid(True)

plt.subplot(224)
plt.plot(x, y4, ':')
plt.xlabel(r'$x$', fontsize=12)
plt.ylabel(r'$y_4$', fontsize=12)

plt.grid(True)

plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(2,2,figsize = (12,7))

axs[0,0].plot(x, y1 , '-')
axs[0,0].set_xlabel(r'$x$')
axs[0,0].set_ylabel(r'$y_1$')
axs[0,0].grid(True)

axs[0,1].plot(x, y2 , '--')
axs[0,1].set_xlabel(r'$x$')
axs[0,1].set_ylabel(r'$y_2$')
axs[0,1].grid(True)

axs[1,0].plot(x, y3, '-.')
axs[1,0].set_xlabel(r'$x$')
axs[1,0].set_ylabel(r'$y_3$')
axs[1,0].grid(True)

axs[1,1].plot(x, y4, ':')
axs[1,1].set_xlabel(r'$x$')
axs[1,1].set_ylabel(r'$y_4$')
axs[1,1].grid(True)

plt.tight_layout()
plt.show()

# %%
x=[1,5,10,15,20]
y1=[1,7,3,5,11]
y2=[4,3,1,8,12]

plt.figure(figsize=(12,7))
plt.plot(x,y1,'o-r',alpha=0.7,label='first',lw=5, mec='b',mew = 2, ms=10)
plt.plot(x,y2,'v-.g',label='second',mec='r',lw=2,mew=2,ms=12)
axs[1,1].set_xlabel(r'$x$')
axs[1,1].set_ylabel(r'$y$')
plt.legend()
plt.grid(True)

# %%
import numpy as np

# %%
x = np.arange(0.0,5,0.01)
y = np.cos(x*np.pi)

# %%
x = np.arange(0.0, 5, 0.01)
y = np.cos(x * np.pi)
plt.plot(x, y, c='r', linewidth=2)
plt.xlabel(r'$x$')
plt.ylabel(r'$y$')
plt.title(r'График функции $y = \cos(x \cdot \pi)$')
plt.grid(True)
plt.fill_between(x, y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.plot(x, y, c='r')
plt.fill_between(x, y, where=(y > 0.75) | (y < -0.75), alpha=0.5)

plt.xlabel(r'$x$', fontsize=12)
plt.ylabel(r'$y$', fontsize=12)
plt.title(r'$y = \sin(x)$', fontsize=14)
plt.grid(True)

plt.show();

# %%
plt.plot(x, y, c='r')
plt.fill_between(x, y, where=(y> 0), alpha=0.5)

plt.xlabel(r'$x$', fontsize=12)
plt.ylabel(r'$y$', fontsize=12)

plt.grid(True)
plt.show();

# %%
plt.plot(x, y, c='r')
plt.grid(True)
plt.fill_between(x, 0.5, y, where=(y >= 0.5), alpha=0.5)

plt.xlabel(r'$x$', fontsize=12)
plt.ylabel(r'$y$', fontsize=12)

plt.show();

# %%
plt.plot(x, y, c='r')
plt.grid(True)
plt.fill_between(x, y, 1, alpha=0.5)

plt.xlabel(r'$x$', fontsize=12)
plt.ylabel(r'$y$', fontsize=12)
plt.show()

# %%
plt.plot(x,y,c='r')
plt.grid()
plt.fill_between(x,y, where=y>=0, color='g', alpha=0.3)
plt.fill_between(x,y, where=y<=0, color='r', alpha=0.3)
plt.xlabel(r'$x$', fontsize=12)
plt.ylabel(r'$y$', fontsize=12)
plt.show()

# %%
x = [1,2,3,4,5,6,7]
y=[7,6,5,4,5,6,7]
plt.xlabel(r'$x$')
plt.ylabel(r'$y$')
plt.grid(True)
plt.plot(x,y,marker='o',c='g');

# %%
x = np.arange(0.0,5,0.01)
y=np.cos(x*np.pi)
plt.plot(x,y, marker='o', c='g')
plt.grid()
plt.xlabel(r'$x$', fontsize=12)
plt.ylabel(r'$y$', fontsize=12)
plt.show()

# %%
x = np.arange(0.0, 5, 0.01)
y = np.cos(x * np.pi)
m_ev_case = [None, 10, (100, 30), slice(100, 400, 15), [0, 100, 200, 300], [10, 50, 100]]

fig, ax = plt.subplots(2, 3, figsize=(10, 7))
axs = [ax[i, j] for i in range(2) for j in range(3)]

for i, case in enumerate(m_ev_case):
    axs[i].set_title(str(case))
    axs[i].plot(x, y, 'o', ls='-', ms=7, markevery=case)
    axs[i].set_xlabel(r'$x$', fontsize=10)
    axs[i].set_ylabel(r'$y$', fontsize=10)
    axs[i].grid(True)

plt.tight_layout()
plt.show()

# %%
x=np.arange(0.0,5,0.01)
y=np.cos(x*np.pi)
plt.xlabel(r'$x$')
plt.ylabel(r'$y$')
plt.title(r'График функции $y = \cos(x \cdot \pi)$')
plt.grid(True)
y_masked = np.ma.masked_where(y<-0.5,y)
plt.ylim(-1,1)

plt.plot(x,y_masked,linewidth=3);

# %%
x=np.arange(0,7)
y=x

where_set=['pre','post','mid']
fig, axs = plt.subplots(1,3,figsize=(15,4))
for i, ax in enumerate(axs):
    ax.set_xlabel(r'$x$')      
    ax.set_ylabel(r'$y$') 
    ax.step(x,y,'g-o', where= where_set[i])
    ax.grid()
